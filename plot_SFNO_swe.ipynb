# %% [markdown]
# # Training a SFNO on the spherical Shallow Water equations
#
# In this example, we demonstrate how to use the small Spherical Shallow Water Equations example we ship with the package
# to train a Spherical Fourier-Neural Operator

# %%
import torch
import matplotlib.pyplot as plt
import sys
import numpy as np

# Neural Operator Imports
from neuralop.models import SFNO
from neuralop import Trainer
#from neuralop.training import AdamW
from neuralop.datasets import load_spherical_swe
from neuralop.utils import count_model_params
from neuralop import LpLoss, H1Loss

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# Uncomment the following line if using progress bars
from tqdm.autonotebook import tqdm, trange
# Out:
# C:\Users\Matteo\AppData\Local\Temp\ipykernel_10424\1567181420.py:17: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %% [markdown]
# Loading the Spherical Shallow Water Equations in multiple resolutions

# %%
train_loader, test_loaders = load_spherical_swe(n_train=200, batch_size=4, train_resolution=(32, 64),
                                                test_resolutions=[(32, 64), (64, 128)], n_tests=[50, 50], test_batch_sizes=[10, 10],)
# Out:
# Loading train dataloader at resolution (32, 64) with 200 samples and batch-size=4
# Loading test dataloader at resolution (32, 64) with 50 samples and batch-size=10
# Loading test dataloader at resolution (64, 128) with 50 samples and batch-size=10

# %%
data_train = train_loader.dataset[0]
x_train = data_train['x']
y_train = data_train['y']
print(f'x_train.shape: {x_train.shape}')
print(f'y_train.shape: {y_train.shape}')
# Out:
# x_train.shape: torch.Size([3, 32, 64])
# y_train.shape: torch.Size([3, 32, 64])

# %%
cmap = 'Blues'

plt.figure(figsize=(12, 5))

plt.subplot(1, 3, 1)
plt.imshow(x_train[0, :, :], cmap=cmap)
plt.colorbar()
plt.title('x_train[0]')
plt.xticks([])
plt.yticks([])

plt.subplot(1, 3, 2)
plt.imshow(x_train[1, :, :], cmap=cmap)
plt.title('x_train[1]')
plt.colorbar()
plt.xticks([])
plt.yticks([])

plt.subplot(1, 3, 3)
plt.imshow(x_train[2, :, :], cmap=cmap)
plt.title('x_train[2]')
plt.colorbar()
plt.xticks([])
plt.yticks([])

plt.show()

plt.figure(figsize=(10, 5))

plt.subplot(1, 3, 1)
plt.imshow(y_train[0, :, :], cmap=cmap)
plt.title('y_train[0]')
plt.xticks([])
plt.yticks([])

plt.subplot(1, 3, 2)
plt.imshow(y_train[1, :, :], cmap=cmap)
plt.title('y_train[1]')
plt.xticks([])
plt.yticks([])

plt.subplot(1, 3, 3)
plt.imshow(y_train[2, :, :], cmap=cmap)
plt.title('y_train[2]')
plt.xticks([])
plt.yticks([])

plt.show()

# %%
#test_samples = test_loaders[(32,64)].dataset
#test_samples[0]

# %% [markdown]
# We create a spherical FNO model

# %%
model = SFNO(n_modes=(16, 16),
             in_channels=3,
             out_channels=3,
             hidden_channels=32,
             projection_channel_ratio=2,
             factorization='dense')
model = model.to(device)

n_params = count_model_params(model)
print(f'\nOur model has {n_params} parameters.')
sys.stdout.flush()
# Out:
# Our model has 153763 parameters.

# %% [markdown]
# Create the optimizer

# %%
learn_rate = 1e-3
optimizer = torch.optim.Adam(model.parameters(), lr=learn_rate)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=30)

# %% [markdown]
# Creating the losses

# %%
l2loss = LpLoss(d=2, p=2, reduce_dims=(0,1))
# h1loss = H1Loss(d=2, reduce_dims=(0,1))

train_loss = l2loss
eval_losses={'l2': l2loss} #'h1': h1loss,

# %%
print('\n### MODEL ###\n', model)
print('\n### OPTIMIZER ###\n', optimizer)
print('\n### SCHEDULER ###\n', scheduler)
print('\n### LOSSES ###')
print(f'\n * Train: {train_loss}')
print(f'\n * Test: {eval_losses}')
sys.stdout.flush()
# Out:
# ### MODEL ###
#  SFNO(
#   (fno_blocks): FNOBlocks(
#     (convs): SphericalConv(
#       (weight): ModuleList(
#         (0-3): 4 x ComplexDenseTensor(shape=torch.Size([32, 32, 16]), rank=None)
#       )
#       (sht_handle): SHT(
#         (_SHT_cache): ModuleDict()
#         (_iSHT_cache): ModuleDict()
#       )
#     )
#     (fno_skips): ModuleList(
#       (0-3): 4 x Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#   )
#   (lifting): MLP(
#     (fcs): ModuleList(
#       (0): Conv2d(3, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (projection): MLP(
#     (fcs): ModuleList(
#       (0): Conv2d(32, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
#
# ### OPTIMIZER ###
#  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.001
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )
#
# ### SCHEDULER ###
#  <torch.optim.lr_scheduler.CosineAnnealingLR object at 0x0000018AAF135970>
#
# ### LOSSES ###
#
#  * Train: <neuralop.losses.data_losses.LpLoss object at 0x0000018AAB6886B0>
#
#  * Test: {'l2': <neuralop.losses.data_losses.LpLoss object at 0x0000018AAB6886B0>}

# %% [markdown]
# Create the trainer

# %%
trainer = Trainer(model=model, n_epochs=20,
                  device=device,
                  wandb_log=False,
                 # eval_interval=3,
                  use_distributed=False,
                  verbose=True)
# Out:
# self.override_load_to_device=False
# self.overrides_loss=False

# %% [markdown]
# Train the model on the spherical SWE dataset

# %%
trainer.train(train_loader=train_loader,
              test_loaders=test_loaders,
              optimizer=optimizer,
              scheduler=scheduler, 
              regularizer=False, 
              training_loss=train_loss,
              eval_losses=eval_losses)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 trainer.train(train_loader=train_loader,
#       2               test_loaders=test_loaders,
#       3               optimizer=optimizer,
#       4               scheduler=scheduler,
#       5               regularizer=False,
#       6               training_loss=train_loss,
#       7               eval_losses=eval_losses)
#
# File c:\Users\Matteo\AppData\Local\Programs\Python\Python312\Lib\site-packages\neuralop\training\trainer.py:221, in Trainer.train(self, train_loader, test_loaders, optimizer, scheduler, regularizer, training_loss, eval_losses)
#     216     self.callbacks.on_before_val(epoch=epoch, train_err=train_err, time=epoch_train_time, \
#     217                            avg_loss=avg_loss, avg_lasso_loss=avg_lasso_loss)
#     220 for loader_name, loader in test_loaders.items():
# --> 221     errors = self.evaluate(eval_losses, loader, log_prefix=loader_name)
#     223 if self.callbacks:
#     224     self.callbacks.on_val_end()
#
# File c:\Users\Matteo\AppData\Local\Programs\Python\Python312\Lib\site-packages\neuralop\training\trainer.py:271, in Trainer.evaluate(self, loss_dict, data_loader, log_prefix)
#     267 else:
#     268     # load data to device if no preprocessor exists
#     269     sample = {k:v.to(self.device) for k,v in sample.items() if torch.is_tensor(v)}
# --> 271 out = self.model(**sample)
#     273 if self.data_processor is not None:
#     274     out, sample = self.data_processor.postprocess(out, sample)
#
# File c:\Users\Matteo\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Matteo\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\Matteo\AppData\Local\Programs\Python\Python312\Lib\site-packages\neuralop\models\fno.py:253, in FNO.forward(self, x, output_shape, **kwargs)
#     250     x = self.domain_padding.pad(x)
#     252 for layer_idx in range(self.n_layers):
# --> 253     x = self.fno_blocks(x, layer_idx, output_shape=output_shape[layer_idx])
#     255 if self.domain_padding is not None:
#     256     x = self.domain_padding.unpad(x)
#
# File c:\Users\Matteo\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Matteo\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\Matteo\AppData\Local\Programs\Python\Python312\Lib\site-packages\neuralop\layers\fno_block.py:195, in FNOBlocks.forward(self, x, index, output_shape)
#     193     return self.forward_with_preactivation(x, index, output_shape)
#     194 else:
# --> 195     return self.forward_with_postactivation(x, index, output_shape)
#
# File c:\Users\Matteo\AppData\Local\Programs\Python\Python312\Lib\site-packages\neuralop\layers\fno_block.py:208, in FNOBlocks.forward_with_postactivation(self, x, index, output_shape)
#     205 if self.stabilizer == "tanh":
#     206     x = torch.tanh(x)
# --> 208 x_fno = self.convs(x, index, output_shape=output_shape)
#     210 if self.norm is not None:
#     211     x_fno = self.norm[self.n_norms * index](x_fno)
#
# File c:\Users\Matteo\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Matteo\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\Matteo\AppData\Local\Programs\Python\Python312\Lib\site-packages\neuralop\layers\spherical_convolution.py:480, in SphericalConv.forward(self, x, indices, output_shape)
#     470 out_fft = self.sht_handle.sht(x, s=(self.n_modes[0], self.n_modes[1]//2),
#     471                               norm=self.sht_norm, grid=self.sht_grids[indices])
#     473 out_fft = self._contract(
#     474     out_fft[:, :, :self.n_modes[0], :self.n_modes[1]//2],
#     475     self._get_weight(indices)[:, :, :self.n_modes[0]],
#     476     separable=self.separable,
#     477     dhconv=True,
#     478 )
# --> 480 x = self.sht_handle.isht(out_fft, s=(height, width), norm=self.sht_norm,
#     481                          grid=self.sht_grids[indices+1])
#     483 if self.bias is not None:
#     484     x = x + self.bias[indices, ...]
#
# File c:\Users\Matteo\AppData\Local\Programs\Python\Python312\Lib\site-packages\neuralop\layers\spherical_convolution.py:283, in SHT.isht(self, x, s, norm, grid)
#     269     isht = (
#     270         InverseRealSHT(
#     271             nlat=height,
#    (...)
#     279         .to(dtype=self.dtype)
#     280     )
#     281     self._iSHT_cache[cache_key] = isht
# --> 283 return isht(x)
#
# File c:\Users\Matteo\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Matteo\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\Matteo\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch_harmonics\sht.py:188, in InverseRealSHT.forward(self, x)
#     185 # Evaluate associated Legendre functions on the output nodes
#     186 x = torch.view_as_real(x)
# --> 188 rl = torch.einsum('...lm, mlk->...km', x[..., 0], self.pct )
#     189 im = torch.einsum('...lm, mlk->...km', x[..., 1], self.pct )
#     190 xs = torch.stack((rl, im), -1)
#
# File c:\Users\Matteo\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\functional.py:386, in einsum(*args)
#     381     return einsum(equation, *_operands)
#     383 if len(operands) <= 2 or not opt_einsum.enabled:
#     384     # the path for contracting 0 or 1 time(s) is already optimized
#     385     # or the user has disabled using opt_einsum
# --> 386     return _VF.einsum(equation, operands)  # type: ignore[attr-defined]
#     388 path = None
#     389 if opt_einsum.is_available():
#
# KeyboardInterrupt:

# %% [markdown]
# Plot the prediction, and compare with the ground-truth
# Note that we trained on a very small resolution for
# a very small number of epochs
# In practice, we would train at larger resolution, on many more samples.
#
# However, for practicity, we created a minimal example that
# i) fits in just a few Mb of memory
# ii) can be trained quickly on CPU
#
# In practice we would train a Neural Operator on one or multiple GPUs

# %%
fig = plt.figure(figsize=(7, 7))
for index, resolution in enumerate([(32, 64), (64, 128)]):
    test_samples = test_loaders[resolution].dataset
    data = test_samples[0]
    # Input x
    x = data['x']
    # Ground-truth
    y = data['y'][0, ...].numpy()
    # Model prediction
    x_in = x.unsqueeze(0).to(device)
    out = model(x_in).squeeze()[0, ...].detach().cpu().numpy()
    x = x[0, ...].detach().numpy()

    ax = fig.add_subplot(2, 3, index*3 + 1)
    ax.imshow(x)
    ax.set_title(f'Input x {resolution}')
    plt.xticks([], [])
    plt.yticks([], [])

    ax = fig.add_subplot(2, 3, index*3 + 2)
    ax.imshow(y)
    ax.set_title('Ground-truth y')
    plt.xticks([], [])
    plt.yticks([], [])

    ax = fig.add_subplot(2, 3, index*3 + 3)
    ax.imshow(out)
    ax.set_title('Model prediction')
    plt.xticks([], [])
    plt.yticks([], [])

fig.suptitle('Inputs, ground-truth output and prediction.', y=0.98)
plt.tight_layout()
fig.show()
# Out:
# C:\Users\Matteo\AppData\Local\Temp\ipykernel_19860\2782922215.py:34: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
